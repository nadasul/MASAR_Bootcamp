# %% [markdown]
# <a href="https://colab.research.google.com/github/nadasul/MASAR_Bootcamp/blob/main/Data_cleaningipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the needed packages
import seaborn as sn
import pandas as pd

#read the data
df = pd.read_csv('https://raw.githubusercontent.com/DSomair/Masar_DS/main/Datasets/Week2/diabetes_unclean.csv')
diabetes_unc = df

# %%
# let's explore the data

df.head()
# Out:
#     ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
# get the column
df.columns
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %%
#rename columns
df.rename(columns={'No_Pation':'Pat_ID'}, inplace=True)

# %%
#check the null (missing values)
df.isnull()
d = 'Y'
dd= ' Y'
ddd= '  Y'
d_1 = ''

# %%
#check how many missing values
df.isnull().sum()
# Out:
# ID        0
# Pat_ID    0
# Gender    0
# AGE       1
# Urea      1
# Cr        2
# HbA1c     3
# Chol      2
# TG        2
# HDL       1
# LDL       2
# VLDL      1
# BMI       0
# CLASS     0
# dtype: int64

# %%
#replace the missing value(s) with mean

df['HbA1c'] = df['HbA1c'].fillna(df['HbA1c'].mean())

# %%
# dropping the missing values
df_new = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1009 non-null   int64
#  1   Pat_ID  1009 non-null   int64
#  2   Gender  1009 non-null   object
#  3   AGE     1008 non-null   float64
#  4   Urea    1008 non-null   float64
#  5   Cr      1007 non-null   float64
#  6   HbA1c   1009 non-null   float64
#  7   Chol    1007 non-null   float64
#  8   TG      1007 non-null   float64
#  9   HDL     1008 non-null   float64
#  10  LDL     1007 non-null   float64
#  11  VLDL    1008 non-null   float64
#  12  BMI     1009 non-null   float64
#  13  CLASS   1009 non-null   object
# dtypes: float64(10), int64(2), object(2)
# memory usage: 110.5+ KB

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 997 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      997 non-null    int64
#  1   Pat_ID  997 non-null    int64
#  2   Gender  997 non-null    object
#  3   AGE     997 non-null    float64
#  4   Urea    997 non-null    float64
#  5   Cr      997 non-null    float64
#  6   HbA1c   997 non-null    float64
#  7   Chol    997 non-null    float64
#  8   TG      997 non-null    float64
#  9   HDL     997 non-null    float64
#  10  LDL     997 non-null    float64
#  11  VLDL    997 non-null    float64
#  12  BMI     997 non-null    float64
#  13  CLASS   997 non-null    object
# dtypes: float64(10), int64(2), object(2)
# memory usage: 116.8+ KB

# %%
#check the class column values
df_new['CLASS'].unique()
# Out:
# array(['N', 'N ', 'P', 'Y', 'Y '], dtype=object)

# %%
#replace the white spaces
df_new.CLASS = df_new.CLASS.str.replace('Y ', 'Y')
df_new.CLASS = df_new.CLASS.str.replace('N ', 'N')
# Out:
# <ipython-input-17-cd72a9a86a36>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.CLASS = df_new.CLASS.str.replace('Y ', 'Y')
# <ipython-input-17-cd72a9a86a36>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.CLASS = df_new.CLASS.str.replace('N ', 'N')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Set up the matplotlib figure
plt.figure(figsize=(10, 6))

# Create boxplots for each column using seaborn
sns.boxplot(data=df_new
            , orient='v', palette='Set2')

# Set plot labels and title
plt.xlabel('Columns')
plt.ylabel('Values')
plt.title('Boxplot for Each Column')

# Show the plot
plt.show()

# %%
# Select only numeric columns
numeric_columns = df_new.select_dtypes(include='number').columns

# Set up the matplotlib figure with subplots
fig, axes = plt.subplots(nrows=len(numeric_columns), ncols=1, figsize=(8, 111))

# Create individual boxplots for each numeric column using seaborn
for i, column in enumerate(numeric_columns):
    sns.boxplot(y=df_new[column], ax=axes[i])
    axes[i].set_title(column)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
df_new['Cr'].max()
#max value

df_new.describe()
# Out:
#                ID        Pat_ID         AGE        Urea          Cr  \
# count  997.000000  9.970000e+02  997.000000  997.000000  997.000000
# mean   341.125376  2.724397e+05   53.606820    5.127325   68.755266
# std    240.479707  3.385816e+06    8.746421    2.944118   60.000956
# min      1.000000  1.230000e+02   25.000000    0.500000    6.000000
# 25%    125.000000  2.406300e+04   51.000000    3.700000   48.000000
# 50%    302.000000  3.439400e+04   55.000000    4.600000   60.000000
# 75%    551.000000  4.538400e+04   59.000000    5.700000   73.000000
# max    800.000000  7.543566e+07   79.000000   38.900000  800.000000
#
#             HbA1c        Chol          TG         HDL         LDL        VLDL  \
# count  997.000000  997.000000  997.000000  997.000000  997.000000  997.000000
# mean     8.286372    4.862307    2.346048    1.205667    2.611123    1.857573
# std      2.538746    1.298706    1.398546    0.661317    1.116322    3.668713
# min      0.900000    0.000000    0.300000    0.200000    0.300000    0.100000
# 25%      6.500000    4.000000    1.500000    0.900000    1.800000    0.700000
# 50%      8.000000    4.800000    2.000000    1.100000    2.500000    0.900000
# 75%     10.200000    5.600000    2.900000    1.300000    3.300000    1.500000
# max     16.000000   10.300000   13.800000    9.900000    9.900000   35.000000
#
#               BMI
# count  997.000000
# mean    29.591795
# std      4.960851
# min     19.000000
# 25%     26.000000
# 50%     30.000000
# 75%     33.000000
# max     47.750000

# %%
df_new[df_new.Cr > 400]
# Out:
#       ID  Pat_ID Gender   AGE  Urea     Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 273    1   34325      M  58.0  20.8  800.0    9.1   6.6  2.9  1.1  4.3   1.3
# 283  266   24060      M  58.0  20.8  800.0    9.1   6.6  2.9  1.1  4.3   1.3
# 589  136    7747      F  61.0  24.0  401.0    7.0   4.3  2.9  0.4  2.7   1.3
# 590  363   34455      F  55.0  24.0  401.0    6.3   4.3  2.9  0.4  2.7   1.3
# 592  540    2570      F  61.0  24.0  401.0    7.0   4.3  2.9  0.4  2.7   1.3
# 846    1   34325      M  56.0  20.8  800.0    9.0   4.6  2.0  1.2  2.5   0.9
# 860   19   51623      M  60.0  20.8  800.0    9.0   2.3  1.1  0.9  0.9   0.5
#
#       BMI CLASS
# 273  33.0     Y
# 283  33.0     Y
# 589  30.0     Y
# 590  28.0     Y
# 592  36.6     Y
# 846  35.0     Y
# 860  33.0     Y

# %%
df_2 = df_new[df_new.Cr > 401]

# %%
df_2
# Out:
#       ID  Pat_ID Gender   AGE  Urea     Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 273    1   34325      M  58.0  20.8  800.0    9.1   6.6  2.9  1.1  4.3   1.3
# 283  266   24060      M  58.0  20.8  800.0    9.1   6.6  2.9  1.1  4.3   1.3
# 846    1   34325      M  56.0  20.8  800.0    9.0   4.6  2.0  1.2  2.5   0.9
# 860   19   51623      M  60.0  20.8  800.0    9.0   2.3  1.1  0.9  0.9   0.5
#
#       BMI CLASS
# 273  33.0     Y
# 283  33.0     Y
# 846  35.0     Y
# 860  33.0     Y

# %%
# check for duplicate values
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1004    False
# 1005    False
# 1006    False
# 1007    False
# 1008    False
# Length: 1009, dtype: bool

# %%
#remove duplication

df_2 = df_2.drop_duplicates()

# %%
#saving the new dataframe into a csv file

df_2.to_csv('abdul_clean_dia.csv')
